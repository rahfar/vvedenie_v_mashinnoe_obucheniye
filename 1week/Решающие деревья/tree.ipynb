# %%
import numpy as np
from sklearn.tree import DecisionTreeClassifier

# %%
clf = DecisionTreeClassifier(random_state=241)

# %%
import pandas as pd

# %%
durty_data = pd.read_csv('titanic.csv')

# %%
durty_data.shape
# Out:
# (891, 12)

# %%
df = durty_data[['Pclass','Fare','Age','Sex']].copy()

# %%
print(df.head(), df.shape, sep='\n')
# Out:
#    Pclass     Fare   Age     Sex
# 0       3   7.2500  22.0    male
# 1       1  71.2833  38.0  female
# 2       3   7.9250  26.0  female
# 3       1  53.1000  35.0  female
# 4       3   8.0500  35.0    male
# (891, 4)

# %%
df.dropna(inplace=True)

# %% [markdown]
# female=0
# male=1

# %%
df.replace(to_replace=['male', 'female'], value=[1, 0], inplace=True)

# %%
df
# Out:
#      Pclass      Fare   Age  Sex
# 0         3    7.2500  22.0    1
# 1         1   71.2833  38.0    0
# 2         3    7.9250  26.0    0
# 3         1   53.1000  35.0    0
# 4         3    8.0500  35.0    1
# 6         1   51.8625  54.0    1
# 7         3   21.0750   2.0    1
# 8         3   11.1333  27.0    0
# 9         2   30.0708  14.0    0
# 10        3   16.7000   4.0    0
# 11        1   26.5500  58.0    0
# 12        3    8.0500  20.0    1
# 13        3   31.2750  39.0    1
# 14        3    7.8542  14.0    0
# 15        2   16.0000  55.0    0
# 16        3   29.1250   2.0    1
# 18        3   18.0000  31.0    0
# 20        2   26.0000  35.0    1
# 21        2   13.0000  34.0    1
# 22        3    8.0292  15.0    0
# 23        1   35.5000  28.0    1
# 24        3   21.0750   8.0    0
# 25        3   31.3875  38.0    0
# 27        1  263.0000  19.0    1
# 30        1   27.7208  40.0    1
# 33        2   10.5000  66.0    1
# 34        1   82.1708  28.0    1
# ...

# %%
y = durty_data[durty_data['Age'].notna()].Survived.copy()

# %%
y.shape
# Out:
# (714,)

# %%
clf.fit(df, y)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=2,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=241,
#             splitter='best')

# %%
clf.predict([[3, 10, 20, 0]])
# Out:
# array([0], dtype=int64)

# %%
clf.feature_importances_
# Out:
# array([0.14000522, 0.30343647, 0.2560461 , 0.30051221])
